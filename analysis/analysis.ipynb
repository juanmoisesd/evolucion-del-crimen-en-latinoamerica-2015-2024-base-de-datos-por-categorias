# %% [markdown]
# # Evolución del Crimen en Latinoamérica 2015-2024: Base de Datos por Categorías
#
# **DOI:** [10.5281/zenodo.18740062](https://doi.org/10.5281/zenodo.18740062)
# **Author:** de la Serna Tuya, Juan Moisés · ORCID: 0000-0002-8401-8018
# **License:** CC0 1.0
#
# ---
#
# Base de datos sobre la evoluci&oacute;n del crimen en Am&eacute;rica Latina y el Caribe durante el per&iacute;odo 2015-2024, compilada a partir de fuentes secundarias (UNODC, Insight Crime, Prosegur Research, Banco Mundial, CEPAL, ONU Mujeres e Infosegura). El dataset incluye 230 registros organizados por 8 categor&iacute;as: (1) Homicidios: tasas por 100,000 hab. para M&eacute;xico, Brasil, Venez
#
# **Keywords:** crimen, homicidios, Latinoamérica, narcotráfico, violencia, seguridad, femicidio, crimen organizado, estadísticas criminales, América Latina

# %%
# Install dependencies if needed
# !pip install pandas matplotlib seaborn numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120
print('Libraries loaded.')

# %% [markdown]
# ## 1. Load Dataset

# %%
# Download from: https://doi.org/10.5281/zenodo.18740062
# df = pd.read_csv('dataset.csv')

# Synthetic example data
np.random.seed(42)
years = list(range(2000, 2024))
keywords = ['crimen', 'homicidios', 'Latinoamérica', 'narcotráfico']
df = pd.DataFrame({'year': years,
    **{k.replace(' ','_')[:12]: np.random.normal(50,15,len(years)) for k in keywords}})

print(f'Dataset: Evolución del Crimen en Latinoamérica 2015-2024: B')
print(f'DOI: 10.5281/zenodo.18740062')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## 2. Summary Statistics

# %%
df.describe().round(2)

# %% [markdown]
# ## 3. Temporal Trends

# %%
fig, ax = plt.subplots(figsize=(10,5))
for col in df.columns[1:]:
    ax.plot(df['year'], df[col], marker='o', markersize=3, label=col)
ax.set_title('Evolución del Crimen en Latinoamérica 2015-2024: Base d')
ax.set_xlabel('Year')
ax.set_ylabel('Value')
ax.legend(fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Citation

# %%
print('APA:')
print('de la Serna Tuya, Juan Moisés (2026). Evolución del Crimen en Latinoamérica 2015-2024: Base de Datos por Cat. Zenodo. https://doi.org/10.5281/zenodo.18740062')
